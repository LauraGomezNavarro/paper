# %%
import time

print 'Last update:', time.ctime(time.time())
# Out:
# Last update: Tue Jan 14 17:08:38 2020

# %% [markdown]
# (adapted from: http://localhost:8888/notebooks/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/2019-10-01_var_reg2_spectra_all_min_MSR_errorbarsSH_NOISE.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.style
import matplotlib as mpl

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext version_information
# %version_information numpy, matplotlib, ipykernel, jupyter, notebook
# Out:
# Software versions
# Python 2.7.11 64bit [GCC 4.2.1 (Based on Apple Inc. build 5658) (LLVM build 2336.11.00)]
# IPython 5.8.0
# OS Darwin 16.7.0 x86_64 i386 64bit
# numpy 1.16.4
# matplotlib 2.2.2
# ipykernel 4.10.1
# jupyter 1.0.0
# notebook 5.7.8
# Tue Jan 14 17:08:40 2020 CET

# %%
mpl.style.use('classic')
mpl.rcParams['mathtext.fontset'] = 'custom'
mpl.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
mpl.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
mpl.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'

# %% [markdown]
# # Loading the original data:

# %%
spectra_orig_JAS12 = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_JAS12_bothpasses.npz')
spectra_orig_FMA13 = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_FMA13_bothpasses.npz')
spectra_orig_JAS13 = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_JAS13_bothpasses.npz')

spectra_orig_JAS12_K = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_JAS12_bothpasses_K.npz')
spectra_orig_FMA13_K = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_FMA13_bothpasses_K.npz')
spectra_orig_JAS13_K = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_JAS13_bothpasses_K.npz')

# %%
spectra_orig_JAS12_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_JAS12_NOISE.npz')
spectra_orig_FMA13_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_FMA13_NOISE.npz')
spectra_orig_JAS13_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_JAS13_NOISE.npz')

spectra_orig_JAS12_K_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_JAS12_K_NOISE.npz')
spectra_orig_FMA13_K_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_FMA13_K_NOISE.npz')
spectra_orig_JAS13_K_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_orig_JAS13_K_NOISE.npz')

# %% [markdown]
# # Loading the filtered data spectra:

# %% [markdown]
# * Reg 2:

# %%
data_varreg2_v3_JAS12_K = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v3_JAS12_K.npz')
data_varreg2_v3_JAS12_K_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v3_JAS12_K_NOISE.npz')

# %%
data_varreg2_v7_9_FMA13_K = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v7_FMA13_K_9.npz')
data_varreg2_v7_9_FMA13_K_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v7_FMA13_K_9_NOISE.npz')

# %%
data_varreg2_v3_JAS13_K = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v3_JAS13_K.npz')
data_varreg2_v3_JAS13_K_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v3_JAS13_K_NOISE.npz')

# %%
data_varreg2_v3_JAS12 = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v3_JAS12.npz')
data_varreg2_v3_JAS12_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v3_JAS12_NOISE.npz')

# %%
data_varreg2_v7_FMA13 = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v7_FMA13.npz')
data_varreg2_v7_FMA13_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v7_FMA13_NOISE.npz')

# %%
data_varreg2_v3_JAS13 = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v3_JAS13.npz')
data_varreg2_v3_JAS13_N = np.load('/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/spectra/spectra_varreg2_v3_JAS13_NOISE.npz')

# %%
lambdas_reg2_v3 = data_varreg2_v3_JAS12.f.lambdas
lambdas_reg2_v7 = data_varreg2_v7_FMA13.f.lambdas
lambdas_reg2_v7_9 = data_varreg2_v7_9_FMA13_K.f.lambdas

# %% [markdown]
# ### Shape of vYf_s_f is: file(cycle), wavlength, lambda

# %% [markdown]
# # Spectra of lambda values giving the lowest RMSE values (table):

# %%
fig = plt.figure(figsize=(14,10)) 
fig.patch.set_facecolor('None')

########################################################
# KaRIn

# JAS12 SSH:
ax1 = plt.subplot(231)

ax1.fill_between(spectra_orig_JAS12_K.f.wk_m
                 , np.nanpercentile(spectra_orig_JAS12_K.f.vYf_s_m, 5, axis=0)
                 , np.nanpercentile(spectra_orig_JAS12_K.f.vYf_s_m, 95, axis=0), alpha=.2, color='r')
ax1.loglog(spectra_orig_JAS12_K.f.wk_m, np.nanmean(spectra_orig_JAS12_K.f.vYf_s_m, axis=0), 'r', label='SSH_model', linewidth=2) #
ax1.fill_between(spectra_orig_JAS12_K.f.wk_m
                 , np.nanpercentile(spectra_orig_JAS12_K.f.vYf_s_o, 5, axis=0)
                 , np.nanpercentile(spectra_orig_JAS12_K.f.vYf_s_o, 95, axis=0), alpha=.2, color='k')
ax1.loglog(spectra_orig_JAS12_K.f.wk_m, np.nanmean(spectra_orig_JAS12_K.f.vYf_s_o, axis=0), 'k', label='SSH_obs', linewidth=2)
ax1.loglog(spectra_orig_JAS12_K_N.f.wk_f, np.nanmean(spectra_orig_JAS12_K_N.f.vYf_s_f_n, axis=0), '--k', label='noise', linewidth=2) #

#####2
ii = np.where(lambdas_reg2_v3[:,1] == 380.)[0][0]
labelf = '$\lambda_2$ = ' + str(int(lambdas_reg2_v3[ii,1])) 
p_ssh_filt = np.nanmean(data_varreg2_v3_JAS12_K.f.vYf_s_f[:,:,ii], axis=0)
p_ssh_filt_n = np.nanmean(data_varreg2_v3_JAS12_K_N.f.vYf_s_f_n[:,:,ii], axis=0)
p_ssh_filt05 = np.nanpercentile(data_varreg2_v3_JAS12_K.f.vYf_s_f[:,:,ii], 5, axis=0)
p_ssh_filt95 = np.nanpercentile(data_varreg2_v3_JAS12_K.f.vYf_s_f[:,:,ii], 95, axis=0)
ax1.fill_between(data_varreg2_v3_JAS12_K.f.wk_f, p_ssh_filt05, p_ssh_filt95, alpha=.2)
ax1.loglog(data_varreg2_v3_JAS12_K.f.wk_f, p_ssh_filt, '-', color='b', label='SSH_obs_f', linewidth=2)
ax1.loglog(data_varreg2_v3_JAS12_K_N.f.wk_f, p_ssh_filt_n, '--', color='b', label='noise_f', linewidth=2)

ax1.grid(b=True, which='major', linestyle='-') #, color='gray')
ax1.grid(b=True, which='minor', linestyle='-', color='gray', alpha=0.5)
ax1.set_xlim([200, 9.])
ax1.set_ylim([1e-5, 1e2])
ax1.set_title('JAS12')
ax1.set_ylabel('$Just$ $KaRIn$ \n $SSH$ $PSD$ $[m^2/cy/km]$', size=12) #Min. SSH \n 
ax1.text(.8, .9, labelf, horizontalalignment='center',
     verticalalignment='center',
     transform = ax1.transAxes)

# FMA13 SSH:
ax1 = plt.subplot(232)

ax1.fill_between(spectra_orig_FMA13_K.f.wk_m
                 , np.nanpercentile(spectra_orig_FMA13_K.f.vYf_s_m, 5, axis=0)
                 , np.nanpercentile(spectra_orig_FMA13_K.f.vYf_s_m, 95, axis=0), alpha=.2, color='r')
ax1.loglog(spectra_orig_FMA13_K.f.wk_m, np.nanmean(spectra_orig_FMA13_K.f.vYf_s_m, axis=0), 'r', label='SSH_model', linewidth=2) #
ax1.fill_between(spectra_orig_FMA13_K.f.wk_m
                 , np.nanpercentile(spectra_orig_FMA13_K.f.vYf_s_o, 5, axis=0)
                 , np.nanpercentile(spectra_orig_FMA13_K.f.vYf_s_o, 95, axis=0), alpha=.2, color='k')
ax1.loglog(spectra_orig_FMA13_K.f.wk_m, np.nanmean(spectra_orig_FMA13_K.f.vYf_s_o, axis=0), 'k', label='SSH_obs', linewidth=2) #
ax1.loglog(spectra_orig_FMA13_K_N.f.wk_f, np.nanmean(spectra_orig_FMA13_K_N.f.vYf_s_f_n, axis=0), '--k', label='noise', linewidth=2) #

#####2
ii = np.where(lambdas_reg2_v7_9[:,1] == 95.)[0][0]
labelf = '$\lambda_2$ = ' + str(int(lambdas_reg2_v7[ii,1])) 
p_ssh_filt = np.nanmean(data_varreg2_v7_9_FMA13_K.f.vYf_s_f[:,:,ii], axis=0)
p_ssh_filt_n = np.nanmean(data_varreg2_v7_9_FMA13_K_N.f.vYf_s_f_n[:,:,ii], axis=0)
p_ssh_filt05 = np.nanpercentile(data_varreg2_v7_9_FMA13_K.f.vYf_s_f[:,:,ii], 5, axis=0)
p_ssh_filt95 = np.nanpercentile(data_varreg2_v7_9_FMA13_K.f.vYf_s_f[:,:,ii], 95, axis=0)
ax1.fill_between(data_varreg2_v7_9_FMA13_K.f.wk_f, p_ssh_filt05, p_ssh_filt95, alpha=.2)
ax1.loglog(data_varreg2_v7_9_FMA13_K.f.wk_f, p_ssh_filt, '-', color='b', label='SSH_obs_f', linewidth=2)
ax1.loglog(data_varreg2_v7_9_FMA13_K_N.f.wk_f, p_ssh_filt_n, '--', color='b', label='noise_f', linewidth=2)

ax1.grid(b=True, which='major', linestyle='-') #, color='gray')
ax1.grid(b=True, which='minor', linestyle='-', color='gray', alpha=0.5)
ax1.set_xlim([200, 9.])
ax1.set_ylim([1e-5, 1e2])
ax1.set_title('FMA13')
ax1.text(.8, .9, labelf, horizontalalignment='center',
     verticalalignment='center',
     transform = ax1.transAxes)

# JAS13 SSH:
ax1 = plt.subplot(233)

ax1.fill_between(spectra_orig_JAS13_K.f.wk_m
                 , np.nanpercentile(spectra_orig_JAS13_K.f.vYf_s_m, 5, axis=0)
                 , np.nanpercentile(spectra_orig_JAS13_K.f.vYf_s_m, 95, axis=0), alpha=.2, color='r')
ax1.loglog(spectra_orig_JAS13_K.f.wk_m, np.nanmean(spectra_orig_JAS13_K.f.vYf_s_m, axis=0), 'r', label='SSH_model', linewidth=2) #
ax1.fill_between(spectra_orig_JAS13_K.f.wk_m
                 , np.nanpercentile(spectra_orig_JAS13_K.f.vYf_s_o, 5, axis=0)
                 , np.nanpercentile(spectra_orig_JAS13_K.f.vYf_s_o, 95, axis=0), alpha=.2, color='k')
ax1.loglog(spectra_orig_JAS13_K.f.wk_m, np.nanmean(spectra_orig_JAS13_K.f.vYf_s_o, axis=0), 'k', label='SSH_obs', linewidth=2) #
ax1.loglog(spectra_orig_JAS13_K_N.f.wk_f, np.nanmean(spectra_orig_JAS13_K_N.f.vYf_s_f_n, axis=0), '--k', label='noise', linewidth=2) #

#####2
ii = np.where(lambdas_reg2_v3[:,1] == 380.)[0][0]
labelf = '$\lambda_2$ = ' + str(int(lambdas_reg2_v3[ii,1])) 
p_ssh_filt = np.nanmean(data_varreg2_v3_JAS13_K.f.vYf_s_f[:,:,ii], axis=0)
p_ssh_filt_n = np.nanmean(data_varreg2_v3_JAS13_K_N.f.vYf_s_f_n[:,:,ii], axis=0)
p_ssh_filt05 = np.nanpercentile(data_varreg2_v3_JAS13_K.f.vYf_s_f[:,:,ii], 5, axis=0)
p_ssh_filt95 = np.nanpercentile(data_varreg2_v3_JAS13_K.f.vYf_s_f[:,:,ii], 95, axis=0)
ax1.fill_between(data_varreg2_v3_JAS13_K.f.wk_f, p_ssh_filt05, p_ssh_filt95, alpha=.2)
ax1.loglog(data_varreg2_v3_JAS13_K.f.wk_f, p_ssh_filt, '-', color='b', label='SSH_obs_f', linewidth=2)
ax1.loglog(data_varreg2_v3_JAS13_K_N.f.wk_f, p_ssh_filt_n, '--', color='b', label='noise_f', linewidth=2)

ax1.grid(b=True, which='major', linestyle='-') #, color='gray')
ax1.grid(b=True, which='minor', linestyle='-', color='gray', alpha=0.5)
ax1.set_xlim([200, 9.])
ax1.set_ylim([1e-5, 1e2])
ax1.set_title('JAS13')
ax1.text(.8, .9, labelf, horizontalalignment='center',
     verticalalignment='center',
     transform = ax1.transAxes)

####################################################
# All:
# JAS12 SSH:
ax1 = plt.subplot(234)

ax1.fill_between(spectra_orig_JAS12.f.wk_m
                 , np.nanpercentile(spectra_orig_JAS12.f.vYf_s_m, 5, axis=0)
                 , np.nanpercentile(spectra_orig_JAS12.f.vYf_s_m, 95, axis=0), alpha=.2, color='r')
ax1.loglog(spectra_orig_JAS12.f.wk_m, np.nanmean(spectra_orig_JAS12.f.vYf_s_m, axis=0), 'r', label='SSH_model', linewidth=2) #
ax1.fill_between(spectra_orig_JAS12.f.wk_m
                 , np.nanpercentile(spectra_orig_JAS12.f.vYf_s_o, 5, axis=0)
                 , np.nanpercentile(spectra_orig_JAS12.f.vYf_s_o, 95, axis=0), alpha=.2, color='k')
ax1.loglog(spectra_orig_JAS12.f.wk_m, np.nanmean(spectra_orig_JAS12.f.vYf_s_o, axis=0), 'k', label='SSH_obs', linewidth=2)
ax1.loglog(spectra_orig_JAS12_N.f.wk_f, np.nanmean(spectra_orig_JAS12_N.f.vYf_s_f_n, axis=0), '--k', label='noise', linewidth=2) #

#####2
ii = np.where(lambdas_reg2_v3[:,1] == 480.)[0][0]
labelf = '$\lambda_2$ = ' + str(int(lambdas_reg2_v3[ii,1])) 
p_ssh_filt = np.nanmean(data_varreg2_v3_JAS12.f.vYf_s_f[:,:,ii], axis=0)
p_ssh_filt_n = np.nanmean(data_varreg2_v3_JAS12_N.f.vYf_s_f_n[:,:,ii], axis=0)
p_ssh_filt05 = np.nanpercentile(data_varreg2_v3_JAS12.f.vYf_s_f[:,:,ii], 5, axis=0)
p_ssh_filt95 = np.nanpercentile(data_varreg2_v3_JAS12.f.vYf_s_f[:,:,ii], 95, axis=0)
ax1.fill_between(data_varreg2_v3_JAS12.f.wk_f, p_ssh_filt05, p_ssh_filt95, alpha=.2)
ax1.loglog(data_varreg2_v3_JAS12.f.wk_f, p_ssh_filt, '-', color='b', label='SSH_obs_f', linewidth=2)
ax1.loglog(data_varreg2_v3_JAS12_N.f.wk_f, p_ssh_filt_n, '--', color='b', label='noise_f', linewidth=2)

ax1.grid(b=True, which='major', linestyle='-') #, color='gray')
ax1.grid(b=True, which='minor', linestyle='-', color='gray', alpha=0.5)
ax1.set_xlim([200, 9.])
ax1.set_ylim([1e-5, 1e2])
ax1.set_ylabel('$All$ $errors$ \n $SSH$ $PSD$ $[m^2/cy/km]$', size=12) #Min. SSH \n 
ax1.set_xlabel('$Wavelength$ $[km]$', size=12) #Min. SSH \n 
ax1.text(.8, .9, labelf, horizontalalignment='center',
     verticalalignment='center',
     transform = ax1.transAxes)

# FMA13 SSH:
ax1 = plt.subplot(235)

ax1.fill_between(spectra_orig_FMA13.f.wk_m
                 , np.nanpercentile(spectra_orig_FMA13.f.vYf_s_m, 5, axis=0)
                 , np.nanpercentile(spectra_orig_FMA13.f.vYf_s_m, 95, axis=0), alpha=.2, color='r')
ax1.loglog(spectra_orig_FMA13.f.wk_m, np.nanmean(spectra_orig_FMA13.f.vYf_s_m, axis=0), 'r', label='SSH_model', linewidth=2) #
ax1.fill_between(spectra_orig_FMA13.f.wk_m
                 , np.nanpercentile(spectra_orig_FMA13.f.vYf_s_o, 5, axis=0)
                 , np.nanpercentile(spectra_orig_FMA13.f.vYf_s_o, 95, axis=0), alpha=.2, color='k')
ax1.loglog(spectra_orig_FMA13.f.wk_m, np.nanmean(spectra_orig_FMA13.f.vYf_s_o, axis=0), 'k', label='SSH_obs', linewidth=2) #
ax1.loglog(spectra_orig_FMA13_N.f.wk_f, np.nanmean(spectra_orig_FMA13_N.f.vYf_s_f_n, axis=0), '--k', label='noise', linewidth=2) #

#####2
ii = np.where(lambdas_reg2_v7[:,1] == 115.)[0][0]
labelf = '$\lambda_2$ = ' + str(int(lambdas_reg2_v7[ii,1]))
p_ssh_filt = np.nanmean(data_varreg2_v7_FMA13.f.vYf_s_f[:,:,ii], axis=0)
p_ssh_filt_n = np.nanmean(data_varreg2_v7_FMA13_N.f.vYf_s_f_n[:,:,ii], axis=0)
p_ssh_filt05 = np.nanpercentile(data_varreg2_v7_FMA13.f.vYf_s_f[:,:,ii], 5, axis=0)
p_ssh_filt95 = np.nanpercentile(data_varreg2_v7_FMA13.f.vYf_s_f[:,:,ii], 95, axis=0)
ax1.fill_between(data_varreg2_v7_FMA13.f.wk_f, p_ssh_filt05, p_ssh_filt95, alpha=.2)
ax1.loglog(data_varreg2_v7_FMA13.f.wk_f, p_ssh_filt, '-', color='b', label='SSH_obs_f', linewidth=2)
ax1.loglog(data_varreg2_v7_FMA13_N.f.wk_f, p_ssh_filt_n, '--', color='b', label='noise_f', linewidth=2)

ax1.grid(b=True, which='major', linestyle='-') #, color='gray')
ax1.grid(b=True, which='minor', linestyle='-', color='gray', alpha=0.5)
ax1.set_xlim([200, 9.])
ax1.set_ylim([1e-5, 1e2])
ax1.set_xlabel('$Wavelength$ $[km]$', size=12)#, family="DejaVu Sans") #Min. SSH \n 
ax1.text(.8, .9, labelf, horizontalalignment='center',
     verticalalignment='center',
     transform = ax1.transAxes)

# JAS13 SSH:
ax1 = plt.subplot(236)

ax1.fill_between(spectra_orig_JAS13.f.wk_m
                 , np.nanpercentile(spectra_orig_JAS13.f.vYf_s_m, 5, axis=0)
                 , np.nanpercentile(spectra_orig_JAS13.f.vYf_s_m, 95, axis=0), alpha=.2, color='r')
ax1.loglog(spectra_orig_JAS13.f.wk_m, np.nanmean(spectra_orig_JAS13.f.vYf_s_m, axis=0), 'r', label='SSH_model', linewidth=2) #
ax1.fill_between(spectra_orig_JAS13.f.wk_m
                 , np.nanpercentile(spectra_orig_JAS13.f.vYf_s_o, 5, axis=0)
                 , np.nanpercentile(spectra_orig_JAS13.f.vYf_s_o, 95, axis=0), alpha=.2, color='k')
ax1.loglog(spectra_orig_JAS13.f.wk_m, np.nanmean(spectra_orig_JAS13.f.vYf_s_o, axis=0), 'k', label='SSH_obs', linewidth=2) #
ax1.loglog(spectra_orig_JAS13_N.f.wk_f, np.nanmean(spectra_orig_JAS13_N.f.vYf_s_f_n, axis=0), '--k', label='noise', linewidth=2) #

#####2
ii = np.where(lambdas_reg2_v3[:,1] == 480.)[0][0]
labelf = '$\lambda_2$ = ' + str(int(lambdas_reg2_v3[ii,1])) 
p_ssh_filt = np.nanmean(data_varreg2_v3_JAS13.f.vYf_s_f[:,:,ii], axis=0)
p_ssh_filt_n = np.nanmean(data_varreg2_v3_JAS13_N.f.vYf_s_f_n[:,:,ii], axis=0)
p_ssh_filt05 = np.nanpercentile(data_varreg2_v3_JAS13.f.vYf_s_f[:,:,ii], 5, axis=0)
p_ssh_filt95 = np.nanpercentile(data_varreg2_v3_JAS13.f.vYf_s_f[:,:,ii], 95, axis=0)
ax1.fill_between(data_varreg2_v3_JAS13.f.wk_f, p_ssh_filt05, p_ssh_filt95, alpha=.2)
ax1.loglog(data_varreg2_v3_JAS13.f.wk_f, p_ssh_filt, '-', color='b', label='SSH_obs_f', linewidth=2)
ax1.loglog(data_varreg2_v3_JAS13_N.f.wk_f, p_ssh_filt_n, '--', color='b', label='noise_f', linewidth=2)

ax1.grid(b=True, which='major', linestyle='-') #, color='gray')
ax1.grid(b=True, which='minor', linestyle='-', color='gray', alpha=0.5)
ax1.set_xlim([200, 9.])
ax1.set_ylim([1e-5, 1e2])
ax1.set_xlabel('$Wavelength$ $[km]$', size=12)#, fontdict={'family': 'serif',  'color':  'darkred'}) #Min. SSH \n
ax1.legend(loc=3) 
ax1.text(.8, .9, labelf, horizontalalignment='center',
     verticalalignment='center',
     transform = ax1.transAxes)

plt.savefig('figures/spectra_min_MSR_varreg2_all_new_EB_noise.png', bbox_inches='tight', dpi=300) #str(savename)

plt.show()
