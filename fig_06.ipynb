# %%
import time

print 'Last update:', time.ctime(time.time())
# Out:
# Last update: Wed Jan 15 15:33:49 2020

# %% [markdown]
# (adapted from: http://localhost:8888/notebooks/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/KA/2019-09-20_KA_qual_plots_FMA13_p009.ipynb)

# %%
import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext version_information
# %version_information numpy, matplotlib, ipykernel, jupyter, notebook
# Out:
# Software versions
# Python 2.7.11 64bit [GCC 4.2.1 (Based on Apple Inc. build 5658) (LLVM build 2336.11.00)]
# IPython 5.8.0
# OS Darwin 16.7.0 x86_64 i386 64bit
# numpy 1.16.4
# matplotlib 2.2.2
# ipykernel 4.10.1
# jupyter 1.0.0
# notebook 5.7.8
# Wed Jan 15 15:33:50 2020 CET

# %%
from swot_filt_qual_plot_KA import *

# %% [markdown]
# # Choose cycles and pass of var reg 2 to copy here:

# %% [markdown]
# *  Fields of pass 09, cycle 2 of FMA13 dataset compared to the fields filtered with λ2 = 95

# %%
filedir = "/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/"
filedir_den_root = '/params_v7/var_reg2/'

savedir = "figures/"

# %%
levels_ssh = 0
lambdas = np.array([95.])
dseason = 'FMA13'
vms = np.array([-.2, 0.15, 0., 0.01, -0.0009, 0.0009])

# %%
swot_filt_qual_plot(filedir, filedir_den_root, lambdas, levels_ssh, savedir, 2, 9, dseason, vms)
# Out:
# /Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_v2.nc
# /Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/just_karin/MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_v2.nc
# ('Cycle ', 2, 'pass ', 9)
# swot_filt_qual_plot_KA.py:177: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if vms == 'None':
# ('lambda: ', 95.0)
# fileroot
# MED_1km_nogap_FMA13_swotFastPhase_BOX
# filename_den_a
# /Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_v2_denoised_p1_00000_p2_0000095_p3_0000000.nc
# ...

# %%
swot_filt_qual_plot(filedir, filedir_den_root, lambdas, levels_ssh, savedir, 6, 9, dseason, vms)
# Out:
# /Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_v2.nc
# /Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/just_karin/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_v2.nc
# ('Cycle ', 6, 'pass ', 9)
# ('lambda: ', 95.0)
# fileroot
# MED_1km_nogap_FMA13_swotFastPhase_BOX
# filename_den_a
# /Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_v2_denoised_p1_00000_p2_0000095_p3_0000000.nc
# figures/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_params_v7_var_reg2_lambd_00095_KA.png
# ('Figure saved at: ', 'figures/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_params_v7_var_reg2_lambd_00095_KA.png')
