# %%
import time

print 'Last update:', time.ctime(time.time())
# Out:
# Last update: Tue Jan 14 17:07:07 2020

# %% [markdown]
# (adapted from: http://localhost:8888/notebooks/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/2019-09-20_boxc_gaus_A_qual_plots_FMA13_c02_p009.ipynb# and 2019-09-20_boxc_gaus_A_qual_plots_FMA13_c06_p009.ipynb)

# %%
import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext version_information
# %version_information numpy, matplotlib, ipykernel, jupyter, notebook
# Out:
# Software versions
# Python 2.7.11 64bit [GCC 4.2.1 (Based on Apple Inc. build 5658) (LLVM build 2336.11.00)]
# IPython 5.8.0
# OS Darwin 16.7.0 x86_64 i386 64bit
# numpy 1.16.4
# matplotlib 2.2.2
# ipykernel 4.10.1
# jupyter 1.0.0
# notebook 5.7.8
# Tue Jan 14 17:07:08 2020 CET

# %%
from swot_filt_qual_plot_A import *

# %% [markdown]
# # Choose cycles and pass of var reg 2 to copy here:

# %% [markdown]
# *  Fields of pass 09, cycle 2 of FMA13 dataset compared to the fields filtered with λ2 = 95

# %%
# boxc --> value rendering lowest RMSE grad error --> 20
# gaus --> value rendering lowest RMSE grad and lap error --> 6.26
# see RMSE minimum points summary for just KaRIn dataset table in tables .lyx

# %%
filename        = '/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_v2.nc'
filename_den_dp = '/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_v2_denoised_p1_00000_p2_0000095_p3_0000000.nc'
filename_den_bc = '/Users/laura/PhD_private/data/SWOT_box_selections/denoised_180521/boxcar/MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_v2_boxp_0020.nc'
filename_den_ga = '/Users/laura/PhD_private/data/SWOT_box_selections/denoised_180521/gaussian/test05/MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_v2_denoised.nc'

# %%
levels_ssh = 0
nlambda = 95.
dseason = 'FMA13'
vms = np.array([-.2, 0.15, 0., 0.01, -0.0009, 0.0009])

# %%
npass = filename.split('_p')[-1].split('_v')[0]
np.int(npass)
# Out:
# 9

# %%
swot_filt_qual_plot(filename, filename_den_dp, nlambda, filename_den_bc, filename_den_ga, levels_ssh, dseason, vms)
# Out:
# /Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_v2.nc
# ('Cycle ', 2, 'pass ', 9)
# ('lambda: ', 95.0)
# ('file dp: ', '/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_v2_denoised_p1_00000_p2_0000095_p3_0000000.nc')
# ('file bc: ', '/Users/laura/PhD_private/data/SWOT_box_selections/denoised_180521/boxcar/MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_v2_boxp_0020.nc')
# ('file ga: ', '/Users/laura/PhD_private/data/SWOT_box_selections/denoised_180521/gaussian/test05/MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_v2_denoised.nc')
# MED_1km_nogap_FMA13_swotFastPhase_BOX_c02_p009_lambd_0000095_bc_ga_A.png
# ...

# %% [markdown]
# *  Fields of pass 09, cycle 6 of FMA13 dataset compared to the fields filtered with λ2 = 95

# %%
filename        = '/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_v2.nc'
filename_den_dp = '/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_v2_denoised_p1_00000_p2_0000095_p3_0000000.nc'
filename_den_bc = '/Users/laura/PhD_private/data/SWOT_box_selections/denoised_180521//boxcar/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_v2_boxp_0020.nc'
filename_den_ga = '/Users/laura/PhD_private/data/SWOT_box_selections/denoised_180521/gaussian/test05/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_v2_denoised.nc'

# %%
levels_ssh = 0
nlambda = 95.
dseason = 'FMA13'
vms = np.array([-.2, 0.15, 0., 0.01, -0.0009, 0.0009])

# %%
# boxc --> value rendering lowest RMSE grad error --> 20
# gaus --> value rendering lowest RMSE grad and lap error --> 6.26
# see RMSE minimum points summary for just KaRIn dataset table in tables .lyx

# %%
swot_filt_qual_plot(filename, filename_den_dp, nlambda, filename_den_bc, filename_den_ga, levels_ssh, dseason, vms)
# Out:
# /Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_v2.nc
# ('Cycle ', 6, 'pass ', 9)
# ('lambda: ', 95.0)
# ('file dp: ', '/Users/laura/PhD_private/develop/SWOT/Filtering/box_filtering/convergence_180521/tests/diagnostics/just_karin/occigen_outputs/qual_plots/paper/all_noises/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_v2_denoised_p1_00000_p2_0000095_p3_0000000.nc')
# ('file bc: ', '/Users/laura/PhD_private/data/SWOT_box_selections/denoised_180521//boxcar/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_v2_boxp_0020.nc')
# ('file ga: ', '/Users/laura/PhD_private/data/SWOT_box_selections/denoised_180521/gaussian/test05/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_v2_denoised.nc')
# figures/MED_1km_nogap_FMA13_swotFastPhase_BOX_c06_p009_lambd_0000095_bc_ga_A.png
# ...
